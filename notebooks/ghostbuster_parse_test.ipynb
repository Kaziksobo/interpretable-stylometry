# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path("..").resolve()
df = pd.read_feather(PROJECT_ROOT / "data" / "processed" / "constituency_parses.feather")

print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (298941, 6)
# doc_id         str
# domain         str
# source         str
# sent_idx     int64
# sent_text      str
# parse_str      str
# dtype: object
#   doc_id domain source  sent_idx  \
# 0      1  essay  human         0
# 1      1  essay  human         1
# 2      1  essay  human         2
# 3      1  essay  human         3
# 4      1  essay  human         4
#
#                                            sent_text  \
# 0  The 2013 film 12 Years a Slave proved that sla...
# 1  Indeed, the film made $150 million outside the...
# 2  The movie was based on the memoir Twelve Years...
# 3  It tells the story of a free African American ...
# 4  Solomon spent twelve years away from his famil...
#
#                                            parse_str
# 0  (S (NP (NP (DT The) (CD 2013) (NN film)) (NP (...
# 1  (S (ADVP (RB Indeed)) (, ,) (NP (DT the) (NN f...
# 2  (S (NP (DT The) (NN movie)) (VP (VBD was) (VP ...
# 3  (S (NP (PRP It)) (VP (VBZ tells) (NP (NP (DT t...
# ...
